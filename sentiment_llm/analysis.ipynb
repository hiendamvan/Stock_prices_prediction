# %%
import pandas as pd 
df = pd.read_csv('../data/sentiment/TCB_sentiment.csv')
print(df.shape)
df.tail(20)
# Out:
# (117, 6)
#      Unnamed: 0           Thời gian  \
# 97          417  (20/04/2024 11:43)
# 98          418  (15/04/2024 15:44)
# 99          419  (12/04/2024 13:27)
# 100         420  (07/04/2024 07:54)
# 101         422  (28/03/2024 11:39)
# 102         424  (27/03/2024 19:45)
# 103         428  (21/03/2024 07:41)
# 104         430  (15/03/2024 17:30)
# 105         432  (12/03/2024 08:00)
# 106         435  (06/03/2024 08:00)
# 107         440  (23/02/2024 16:25)
# 108         441  (22/02/2024 16:54)
# 109         442  (22/02/2024 10:00)
# 110         445  (16/02/2024 20:22)
# 111         448  (08/02/2024 13:30)
# 112         449  (07/02/2024 08:00)
# 113         452  (25/01/2024 12:57)
# 114         453  (23/01/2024 19:00)
# 115         454  (22/01/2024 20:25)
# 116         455  (22/01/2024 19:09)
#
#                                                Tiêu đề  \
# 97   ĐHĐCĐ Techcombank: Kế hoạch chia cổ tức "khủng...
# 98   Mở app thấy tài khoản 'bay' cả cái nhà, xe ô t...
# ...

# %%
df['sentiment_score'].value_counts()
# Out:
# sentiment_score
#  0.7    16
#  0.8    11
#  0.6     7
#  0.9     7
#  0.3     5
#  0.4     5
#  0.5     4
#  1.0     4
#  0.0     2
#  0.2     2
# -1.0     1
# -0.3     1
# Name: count, dtype: int64
